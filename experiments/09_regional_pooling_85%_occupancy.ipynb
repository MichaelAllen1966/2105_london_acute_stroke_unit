# %% [markdown]
# # London ASU model

# %% [markdown]
# ## Requirements and module imports
#
# Code in this simulation uses a standard Anaconda Python environment (https://www.anaconda.com/distribution/#download-section). Additionally this model uses SimPy3 (https://simpy.readthedocs.io/en/latest/). Install SimPy3 with `pip install 'simpy<4'`.

# %%
import simpy
import inspect
from sim_utils.replication import Replicator
from sim_utils.parameters import Scenario

# %% [markdown]
# ## Set up scenarios
#
# Parameters defined in scenarios will overwrite default values in the parameters python file.

# %%
# Set up a dictionary to hold scenarios
scenarios = {}

# Baseline sceanrio (model defaults)
scenarios['constrained_beds'] = Scenario(
    allow_non_preferred_asu = False)
scenarios['constrained_beds_allow_any_redirect'] = Scenario(
    allow_non_preferred_asu = True,
    restrict_non_preferred_to_regions = False)
scenarios['constrained_beds_allow_region_redirect'] = Scenario(
    allow_non_preferred_asu = True,
    restrict_non_preferred_to_regions = True)

# %% [markdown]
# ## Run model

# %%
replications = 30
replications = Replicator(scenarios, replications)
replications.run_scenarios()
# Out:
#
# Global results (mean)
# ---------------------
# name                      constrained_beds  \
# total_patients                     9,523.0
# total_patients_asu                 5,538.0
# total_patients_displaced               0.0
# total_patients_waited              1,810.0
#
# name                      constrained_beds_allow_any_redirect  \
# total_patients                                        9,523.0
# total_patients_asu                                    5,492.0
# total_patients_displaced                                838.0
# total_patients_waited                                     0.0
#
# name                      constrained_beds_allow_region_redirect
# total_patients                                           9,523.0
# total_patients_asu                                       5,510.0
# total_patients_displaced                                 1,056.0
# total_patients_waited                                      662.0
#
# Average patients waiting for ASU
# --------------------------------
# name
# constrained_beds                         22.8
# constrained_beds_allow_any_redirect       0.0
# constrained_beds_allow_region_redirect    0.9
# Name: asu_patients_unallocated, dtype: float64
#
# Average delay (days) for patients who had to wait
# ---------------------------------------------------
# name
# constrained_beds                         5.5
# constrained_beds_allow_any_redirect      0.0
# constrained_beds_allow_region_redirect   1.5
# Name: 0, dtype: float64
#
# Unit admissions
# ------------------
# name                   constrained_beds  constrained_beds_allow_any_redirect  \
# Barnet General SU                 164.7                                151.8
# Charing Cross SU                  336.1                                334.0
# Chelsea & Wminster SU             188.4                                177.6
# Croydon SU                        263.7                                256.5
# Hillingdon SU                     282.9                                279.0
# Homerton SU                       166.5                                176.7
# Kingston SU                       195.4                                183.1
# King’s College SU                 183.1                                182.3
# Lewisham SU                       538.7                                534.1
# N Middlesex SU                    321.7                                343.9
# Newham General SU                 176.2                                175.3
# Northwick Park SU                 376.4                                379.1
# Princess Royal SU                 275.7                                273.6
# Queens Romford SU                 409.7                                404.5
# St Thomas SU                                             17.4
# University College SU                                    12.9
# W Middlesex SU                                           15.6
# Whipps Cross SU                                          16.6
#
# Unit occupancy (95th percentile)
# -----------------
# name                   constrained_beds  constrained_beds_allow_any_redirect  \
# Barnet General SU                  14.0                                 14.0
# Charing Cross SU                   31.0                                 30.0
# Chelsea & Wminster SU              17.0                                 17.0
# Croydon SU                         24.0                                 24.0
# Hillingdon SU                      26.0                                 26.0
# Homerton SU                        16.0                                 16.0
# Kingston SU                        17.0                                 17.0
# King’s College SU                  18.0                                 18.0
# Lewisham SU                        49.0                                 49.0
# N Middlesex SU                     30.0                                 30.0
# Newham General SU                  16.0                                 16.0
# Northwick Park SU                  34.0                                 34.0
# Princess Royal SU                  26.0                                 26.0
# Queens Romford SU                  38.0                                 38.0
# Royal Free SU                      26.0                                 26.0
# Royal London SU                    11.0                                 11.0
# St George’s SU                     15.0                                 15.0
# St Helier SU                       18.0                                 18.0
# St Thomas SU                       21.0                                 21.0
# University College SU              16.0                                 16.0
# W Middlesex SU                     19.0                                 19.0
# Whipps Cross SU                    19.0                                 19.0
#
# name                   constrained_beds_allow_region_redirect
# Barnet General SU                                        14.0
# Charing Cross SU                                         31.0
# Chelsea & Wminster SU                                    17.0
# Croydon SU                                               24.0
# Hillingdon SU                                            26.0
# Homerton SU                                              16.0
# Kingston SU                                              17.0
# King’s College SU                                        18.0
# Lewisham SU                                              49.0
# N Middlesex SU                                           30.0
# Newham General SU                                        16.0
# Northwick Park SU                                        34.0
# Princess Royal SU                                        26.0
# Queens Romford SU                                        38.0
# Royal Free SU                                            26.0
# Royal London SU                                          11.0
# St George’s SU                                           15.0
# St Helier SU                                             18.0
# St Thomas SU                                             21.0
# University College SU                                    16.0
# W Middlesex SU                                           19.0
# Whipps Cross SU                                          19.0

# %% [markdown]
# ## Show model default parameters
#
# Run the code below to model defaults (these are over-ridden by scenario values above).

# %%
print(inspect.getsource(Scenario.__init__))
# Out:
#     def __init__(self, *initial_data, **kwargs):
#         """Default  parameters"""
#         # Simulation parameters
#         self.sim_warmup = 100
#         self.sim_duration = 365
#
#         # Scale admissions
#         self.scale_admissions = 1.0
#
#         # Patient flow
#         self.require_asu = 0.57
#         self.esd_use = 0.
#         self.esd_asu_los_reduction = 7.0
#         self.los_cv = 0.3
#         self.allow_non_preferred_asu = True
#         self.restrict_non_preferred_to_regions = True
#
#         # Overwrite default values
#         for dictionary in initial_data:
#             for key in dictionary:
#                 setattr(self, key, dictionary[key])
#         for key in kwargs:
#             setattr(self, key, kwargs[key])
