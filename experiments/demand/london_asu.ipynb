# %% [markdown]
# # London ASU model

# %% [markdown]
# ## Requirements and module imports
#
# Code in this simulation uses a standard Anaconda Python environment (https://www.anaconda.com/distribution/#download-section). Additionally this model uses SimPy3 (https://simpy.readthedocs.io/en/latest/). Install SimPy3 with `pip install 'simpy<4'`.

# %%
import simpy
import inspect
from sim_utils.replication import Replicator
from sim_utils.parameters import Scenario

# %% [markdown]
# ## Set up scenarios
#
# Parameters defined in scenarios will overwrite default values in the parameters python file.

# %%
# Set up a dictionary to hold scenarios
scenarios = {}

# Baseline sceanrio (model defaults)
scenarios['demand 1.0'] = Scenario(
    allow_non_preferred_asu = False,
    scale_admissions=1.0)

scenarios['demand 0.95'] = Scenario(
    allow_non_preferred_asu = False,
    scale_admissions=0.95)

scenarios['demand 0.90'] = Scenario(
    allow_non_preferred_asu = False,
    scale_admissions=0.90)

scenarios['demand 0.85'] = Scenario(
    allow_non_preferred_asu = False,
    scale_admissions=0.85)

scenarios['demand 0.80'] = Scenario(
    allow_non_preferred_asu = False,
    scale_admissions=0.80)

scenarios['demand 0.75'] = Scenario(
    allow_non_preferred_asu = False,
    scale_admissions=0.75)

# %% [markdown]
# ## Run model

# %%
replications = 30
replications = Replicator(scenarios, replications)
replications.run_scenarios()
# Out:
#
# Global results (mean)
# ---------------------
# name                      demand 0.75  demand 0.80  demand 0.85  demand 0.90  \
# total_patients                7,142.0      7,619.0      8,095.0      8,571.0
# total_patients_asu            4,166.0      4,441.0      4,700.0      4,979.0
# total_patients_displaced          0.0          0.0          0.0          0.0
# total_patients_waited           161.0        319.0        484.0        785.0
#
# name                      demand 0.95  demand 1.0
# total_patients                9,047.0     9,523.0
# total_patients_asu            5,278.0     5,557.0
# total_patients_displaced          0.0         0.0
# total_patients_waited         1,125.0     1,797.0
#
# Average patients waiting for ASU
# --------------------------------
# name
# demand 0.75    0.9
# demand 0.80    1.9
# demand 0.85    3.5
# demand 0.90    7.1
# demand 0.95   12.2
# demand 1.0    20.7
# Name: asu_patients_unallocated, dtype: float64
#
# Average delay (days) for patients who had to wait
# ---------------------------------------------------
# name
# demand 0.75   3.3
# demand 0.80   3.5
# demand 0.85   3.7
# demand 0.90   4.3
# demand 0.95   4.9
# demand 1.0    5.3
# Name: 0, dtype: float64
#
# Unit admissions
# ------------------
# name                   demand 0.75  demand 0.80  demand 0.85  demand 0.90  \
# Barnet General SU            122.4        133.1        139.3        149.8
# Charing Cross SU             251.5        264.1        285.2        297.9
# Chelsea & Wminster SU        142.0        150.9        157.5        168.6
# Croydon SU                   198.9        217.4        228.9        240.7
# Hillingdon SU                208.0        225.6        234.1        253.9
# Homerton SU                  129.4        135.1        146.0        151.8
# Kingston SU                  150.6        152.0        165.4        173.3
# King’s College SU            137.6        144.3        151.6        161.9
# Lewisham SU                  402.5        430.1        457.8        484.1
# N Middlesex SU               240.6        253.0        276.7        284.8
# Newham General SU            133.3        142.2        149.6        158.5
# Northwick Park SU            282.0        303.3        323.0        339.0
# Princess Royal SU            207.0        224.7        238.9        254.4
# Royal London SU                7.6         8.2
# St George’s SU                11.7        12.3
# St Helier SU                  14.5        15.4
# St Thomas SU                  16.3        16.9
# University College SU         13.4        14.4
# W Middlesex SU                13.7        15.5
# Whipps Cross SU               15.1        15.7
#
# Unit occupancy (95th percentile)
# -----------------
# name                   demand 0.75  demand 0.80  demand 0.85  demand 0.90  \
# Barnet General SU             13.0         14.0         14.0         14.0
# Charing Cross SU              27.0         28.0         28.0         30.0
# Chelsea & Wminster SU         17.0         17.0         17.0         17.0
# Croydon SU                    21.0         22.0         22.0         24.0
# Hillingdon SU                 21.0         24.0         26.0         26.0
# Homerton SU                   14.0         16.0         16.0         15.0
# Kingston SU                   17.0         16.0         17.0         17.0
# King’s College SU             17.0         17.0         16.0         18.0
# Lewisham SU                   39.0         39.0         47.0         46.0
# N Middlesex SU                27.0         28.0         30.0         28.0
# Newham General SU             16.0         15.0         16.0         16.0
# Northwick Park SU             30.0         29.0         32.0         34.0
# Princess Royal SU             24.0         22.0         25.0         26.0
# Queens Romford SU             32.0         34.0         34.0         37.0
# Royal Free SU                 23.0         25.0         24.0         26.0
# Royal London SU               11.0         10.0         11.0         11.0
# St George’s SU                15.0         15.0         15.0         15.0
# St Helier SU                  18.0         18.0         18.0         18.0
# St Thomas SU                  19.0         21.0         21.0         21.0
# University College SU         15.0         16.0         16.0         15.0
# W Middlesex SU                19.0         19.0         19.0         19.0
# Whipps Cross SU               18.0         19.0         19.0         18.0
#
# name                   demand 0.95  demand 1.0
# Barnet General SU             14.0        14.0
# Charing Cross SU              31.0        31.0
# Chelsea & Wminster SU         17.0        17.0
# Croydon SU                    24.0        24.0
# Hillingdon SU                 26.0        26.0
# Homerton SU                   16.0        16.0
# Kingston SU                   17.0        17.0
# King’s College SU             18.0        18.0
# Lewisham SU                   48.0        48.0
# N Middlesex SU                29.0        30.0
# Newham General SU             16.0        16.0
# Northwick Park SU             34.0        34.0
# Princess Royal SU             26.0        26.0
# Queens Romford SU             37.0        38.0
# Royal Free SU                 26.0        26.0
# Royal London SU               11.0        11.0
# St George’s SU                15.0        15.0
# St Helier SU                  18.0        18.0
# St Thomas SU                  21.0        21.0
# University College SU         16.0        16.0
# W Middlesex SU                19.0        19.0
# Whipps Cross SU               19.0        19.0

# %% [markdown]
# ## Show model default parameters
#
# Run the code below to model defaults (these are over-ridden by scenario values above).

# %%
print(inspect.getsource(Scenario.__init__))
# Out:
#     def __init__(self, *initial_data, **kwargs):
#         """Default  parameters"""
#         # Simulation parameters
#         self.sim_warmup = 100
#         self.sim_duration = 365
#
#         # Scale admissions
#         self.scale_admissions = 1.0
#
#         # Patient flow
#         self.require_asu = 0.57
#         self.esd_use = 0.
#         self.esd_asu_los_reduction = 7.0
#         self.los_cv = 0.3
#         self.allow_non_preferred_asu = False
#         self.restrict_non_preferred_to_regions = True
#         self.overwrite_preferred_unit_with_closest = False
#
#         # Overwrite default values
#         for dictionary in initial_data:
#             for key in dictionary:
#                 setattr(self, key, dictionary[key])
#         for key in kwargs:
#             setattr(self, key, kwargs[key])
