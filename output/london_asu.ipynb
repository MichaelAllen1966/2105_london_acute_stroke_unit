# %% [markdown]
# # London ASU model

# %% [markdown]
# ## Requirements and module imports
#
# Code in this simulation uses a standard Anaconda Python environment (https://www.anaconda.com/distribution/#download-section). Additionally this model uses SimPy3 (https://simpy.readthedocs.io/en/latest/). Install SimPy3 with `pip install 'simpy<4'`.

# %%
import simpy
import inspect
from sim_utils.replication import Replicator
from sim_utils.parameters import Scenario

# %% [markdown]
# ## Set up scenarios
#
# Parameters defined in scenarios will overwrite default values in the parameters python file.

# %%
# Set up a dictionary to hold scenarios
scenarios = {}

# Baseline sceanrio (model defaults)
scenarios['constrained_beds'] = Scenario(
    allow_non_preferred_asu = False)
scenarios['constrained_beds_allow_region_redirect'] = Scenario(
    allow_non_preferred_asu = True,
    restrict_non_preferred_to_regions = True)

# %% [markdown]
# ## Run model

# %%
replications = 30
replications = Replicator(scenarios, replications)
replications.run_scenarios()
# Out:
#
# Global results (mean)
# ---------------------
# name                      constrained_beds  \
# total_patients                     9,523.0
# total_patients_asu                 5,509.0
# total_patients_displaced               0.0
# total_patients_waited              1,337.0
#
# name                      constrained_beds_allow_region_redirect
# total_patients                                           9,523.0
# total_patients_asu                                       5,526.0
# total_patients_displaced                                   326.0
# total_patients_waited                                        0.0
#
# Average patients waiting for ASU
# --------------------------------
# name
# constrained_beds                         17.0
# constrained_beds_allow_region_redirect    0.0
# Name: asu_patients_unallocated, dtype: float64
#
# Average delay (days) for patients who had to wait
# ---------------------------------------------------
# name
# constrained_beds                         5.6
# constrained_beds_allow_region_redirect   0.0
# Name: 0, dtype: float64
#
# Unit admissions
# ------------------
# name                   constrained_beds  \
# Barnet General SU                 160.1
# Charing Cross SU                  330.3
# Chelsea & Wminster SU             192.6
# Croydon SU                        263.6
# Hillingdon SU                     281.7
# Homerton SU                       165.1
# Kingston SU                       193.6
# King’s College SU                 178.4
# Lewisham SU                       529.8
# N Middlesex SU                    324.7
# Newham General SU                 172.1
# Northwick Park SU                 379.0
# Princess Royal SU                 283.4
# Queens Romford SU                 411.6
# Royal Free SU                     290.8
# Royal London SU                   111.6
# St George’s SU                    155.0
# St Helier SU                      199.6
# St Thomas SU                      225.5
# University College SU             175.4
# W Middlesex SU                    202.5
# Whipps Cross SU                   205.9
#
# name                   constrained_beds_allow_region_redirect
# Barnet General SU                                       140.8
# Charing Cross SU                                        321.3
# Chelsea & Wminster SU                                   169.5
# Croydon SU                                              245.8
# Hillingdon SU                                           264.3
# Homerton SU                                             154.8
# Kingston SU                                             171.7
# King’s College SU                                       173.3
# Lewisham SU                                             516.0
# N Middlesex SU                                          307.1
# Newham General SU                                       160.3
# Northwick Park SU                                       435.3
# Princess Royal SU                                       326.9
# Queens Romford SU                                       479.7
# Royal Free SU                                           270.2
# Royal London SU                                         101.4
# St George’s SU                                          214.2
# St Helier SU                                            177.3
# St Thomas SU                                            211.8
# University College SU                                   227.3
# W Middlesex SU                                          189.1
# Whipps Cross SU                                         189.0
#
# Unit occupancy (mean)
# -----------------
# name                   constrained_beds  \
# Barnet General SU                  12.0
# Charing Cross SU                   25.7
# Chelsea & Wminster SU              15.0
# Croydon SU                         20.5
# Hillingdon SU                      21.6
# Homerton SU                        13.1
# Kingston SU                        14.8
# King’s College SU                  14.1
# Lewisham SU                        40.3
# N Middlesex SU                     26.0
# Newham General SU                  13.7
# Northwick Park SU                  27.6
# Princess Royal SU                  22.0
# Queens Romford SU                  30.2
# Royal Free SU                      21.7
# Royal London SU                     8.5
# St George’s SU                     12.5
# St Helier SU                       16.1
# St Thomas SU                       16.6
# University College SU              15.4
# W Middlesex SU                     15.1
# Whipps Cross SU                    15.7
#
# name                   constrained_beds_allow_region_redirect
# Barnet General SU                                        10.3
# Charing Cross SU                                         26.4
# Chelsea & Wminster SU                                    13.2
# Croydon SU                                               19.2
# Hillingdon SU                                            20.7
# Homerton SU                                              12.0
# Kingston SU                                              13.8
# King’s College SU                                        14.3
# Lewisham SU                                              39.8
# N Middlesex SU                                           21.9
# Newham General SU                                        12.5
# Northwick Park SU                                        35.8
# Princess Royal SU                                        24.9
# Queens Romford SU                                        35.1
# Royal Free SU                                            21.2
# Royal London SU                                           7.8
# St George’s SU                                           16.0
# St Helier SU                                             12.8
# St Thomas SU                                             16.4
# University College SU                                    17.4
# W Middlesex SU                                           15.1
# Whipps Cross SU                                          14.5
#
# Unit occupancy (95th percentile)
# -----------------
# name                   constrained_beds  \
# Barnet General SU                  14.0
# Charing Cross SU                   31.0
# Chelsea & Wminster SU              17.0
# Croydon SU                         24.0
# Hillingdon SU                      26.0
# Homerton SU                        16.0
# Kingston SU                        17.0
# King’s College SU                  18.0
# Lewisham SU                        49.0
# N Middlesex SU                     30.0
# Newham General SU                  16.0
# Northwick Park SU                  37.0
# Princess Royal SU                  30.0
# Queens Romford SU                  37.0
# Royal Free SU                      26.0
# Royal London SU                    11.0
# St George’s SU                     20.0
# St Helier SU                       18.0
# St Thomas SU                       21.0
# University College SU              23.0
# W Middlesex SU                     19.0
# Whipps Cross SU                    19.0
#
# name                   constrained_beds_allow_region_redirect
# Barnet General SU                                        13.0
# Charing Cross SU                                         31.0
# Chelsea & Wminster SU                                    17.0
# Croydon SU                                               23.0
# Hillingdon SU                                            25.0
# Homerton SU                                              16.0
# Kingston SU                                              17.0
# King’s College SU                                        18.0
# Lewisham SU                                              48.0
# N Middlesex SU                                           28.0
# Newham General SU                                        16.0
# Northwick Park SU                                        49.0
# Princess Royal SU                                        32.0
# Queens Romford SU                                        48.0
# Royal Free SU                                            26.0
# Royal London SU                                          11.0
# St George’s SU                                           27.0
# St Helier SU                                             17.0
# St Thomas SU                                             21.0
# University College SU                                    28.0
# W Middlesex SU                                           19.0
# Whipps Cross SU                                          18.0

# %% [markdown]
# ## Show model default parameters
#
# Run the code below to model defaults (these are over-ridden by scenario values above).

# %%
print(inspect.getsource(Scenario.__init__))
# Out:
#     def __init__(self, *initial_data, **kwargs):
#         """Default  parameters"""
#         # Simulation parameters
#         self.sim_warmup = 100
#         self.sim_duration = 365
#
#         # Scale admissions
#         self.scale_admissions = 1.0
#
#         # Patient flow
#         self.require_asu = 0.57
#         self.esd_use = 0.
#         self.esd_asu_los_reduction = 7.0
#         self.los_cv = 0.3
#         self.allow_non_preferred_asu = True
#         self.restrict_non_preferred_to_regions = True
#
#         # Overwrite default values
#         for dictionary in initial_data:
#             for key in dictionary:
#                 setattr(self, key, dictionary[key])
#         for key in kwargs:
#             setattr(self, key, kwargs[key])
